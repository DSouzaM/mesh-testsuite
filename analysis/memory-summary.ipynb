# %%
import pandas as pd
import csv
import os
from collections import defaultdict

def get_files(folder, parse_name_fn):
    files = os.listdir(folder)
    result = defaultdict(list)
    for file in files:
        if ".tsv" not in file:
            continue
        allocator, run = parse_name_fn(file)
        result[allocator].append(os.path.join(folder, file))
    return result
        
# Returns (allocator, run)
def parse_filename(filename):
    return reversed(filename.split(".")[0].split("-"))
def parse_firefox_filename(filename):
    return filename.split(".")[1:3]

programs = {
    "binarytree": ("results_compiled/memory/binarytree", parse_filename),
    "larson": ("results_compiled/memory/larson", parse_filename),
    "redis": ("results_compiled/memory/redis", parse_filename),
    "firefox": ("results_compiled/memory/firefox", parse_firefox_filename),
    "mysql": ("results_compiled/memory/mysql", parse_filename),
}

# %%
data = {}

for program, (filename, parse_fn) in programs.items():
    data[program] = get_files(filename, parse_fn)
    
data
# Out:
# {'binarytree': defaultdict(list,
#              {'jemalloc': ['results_compiled/memory/binarytree/2-jemalloc.tsv',
#                'results_compiled/memory/binarytree/15-jemalloc.tsv',
#                'results_compiled/memory/binarytree/11-jemalloc.tsv',
#                'results_compiled/memory/binarytree/4-jemalloc.tsv',
#                'results_compiled/memory/binarytree/1-jemalloc.tsv',
#                'results_compiled/memory/binarytree/6-jemalloc.tsv',
#                'results_compiled/memory/binarytree/10-jemalloc.tsv',
#                'results_compiled/memory/binarytree/9-jemalloc.tsv',
#                'results_compiled/memory/binarytree/18-jemalloc.tsv',
#                'results_compiled/memory/binarytree/16-jemalloc.tsv',
#                'results_compiled/memory/binarytree/5-jemalloc.tsv',
#                'results_compiled/memory/binarytree/19-jemalloc.tsv',
#                'results_compiled/memory/binarytree/13-jemalloc.tsv',
#                'results_compiled/memory/binarytree/12-jemalloc.tsv',
#                'results_compiled/memory/binarytree/0-jemalloc.tsv',
#                'results_compiled/memory/binarytree/8-jemalloc.tsv',
#                'results_compiled/memory/binarytree/3-jemalloc.tsv',
#                'results_compiled/memory/binarytree/14-jemalloc.tsv',
#                'results_compiled/memory/binarytree/17-jemalloc.tsv',
#                'results_compiled/memory/binarytree/7-jemalloc.tsv'],
#               'mesh': ['results_compiled/memory/binarytree/12-mesh.tsv',
#                'results_compiled/memory/binarytree/10-mesh.tsv',
#                'results_compiled/memory/binarytree/7-mesh.tsv',
#                'results_compiled/memory/binarytree/8-mesh.tsv',
#                'results_compiled/memory/binarytree/17-mesh.tsv',
#                'results_compiled/memory/binarytree/6-mesh.tsv',
#                'results_compiled/memory/binarytree/3-mesh.tsv',
#                'results_compiled/memory/binarytree/9-mesh.tsv',
#                'results_compiled/memory/binarytree/5-mesh.tsv',
#                'results_compiled/memory/binarytree/16-mesh.tsv',
#                'results_compiled/memory/binarytree/11-mesh.tsv',
#                'results_compiled/memory/binarytree/2-mesh.tsv',
#                'results_compiled/memory/binarytree/1-mesh.tsv',
#                'results_compiled/memory/binarytree/19-mesh.tsv',
#                'results_compiled/memory/binarytree/4-mesh.tsv',
#                'results_compiled/memory/binarytree/13-mesh.tsv',
#                'results_compiled/memory/binarytree/14-mesh.tsv',
#                'results_compiled/memory/binarytree/0-mesh.tsv',
#                'results_compiled/memory/binarytree/18-mesh.tsv',
#                'results_compiled/memory/binarytree/15-mesh.tsv'],
#               'malloc': ['results_compiled/memory/binarytree/9-malloc.tsv',
#                'results_compiled/memory/binarytree/5-malloc.tsv',
#                'results_compiled/memory/binarytree/1-malloc.tsv',
#                'results_compiled/memory/binarytree/18-malloc.tsv',
#                'results_compiled/memory/binarytree/12-malloc.tsv',
#                'results_compiled/memory/binarytree/11-malloc.tsv',
#                'results_compiled/memory/binarytree/13-malloc.tsv',
#                'results_compiled/memory/binarytree/14-malloc.tsv',
#                'results_compiled/memory/binarytree/7-malloc.tsv',
#                'results_compiled/memory/binarytree/8-malloc.tsv',
#                'results_compiled/memory/binarytree/15-malloc.tsv',
#                'results_compiled/memory/binarytree/17-malloc.tsv',
#                'results_compiled/memory/binarytree/16-malloc.tsv',
#                'results_compiled/memory/binarytree/19-malloc.tsv',
#                'results_compiled/memory/binarytree/2-malloc.tsv',
#                'results_compiled/memory/binarytree/10-malloc.tsv',
#                'results_compiled/memory/binarytree/6-malloc.tsv',
#                'results_compiled/memory/binarytree/3-malloc.tsv',
#                'results_compiled/memory/binarytree/4-malloc.tsv',
#                'results_compiled/memory/binarytree/0-malloc.tsv']}),
#  'larson': defaultdict(list,
#              {'jemalloc': ['results_compiled/memory/larson/2-jemalloc.tsv',
#                'results_compiled/memory/larson/15-jemalloc.tsv',
#                'results_compiled/memory/larson/11-jemalloc.tsv',
#                'results_compiled/memory/larson/4-jemalloc.tsv',
#                'results_compiled/memory/larson/1-jemalloc.tsv',
#                'results_compiled/memory/larson/6-jemalloc.tsv',
#                'results_compiled/memory/larson/10-jemalloc.tsv',
#                'results_compiled/memory/larson/9-jemalloc.tsv',
#                'results_compiled/memory/larson/18-jemalloc.tsv',
#                'results_compiled/memory/larson/16-jemalloc.tsv',
#                'results_compiled/memory/larson/5-jemalloc.tsv',
#                'results_compiled/memory/larson/19-jemalloc.tsv',
#                'results_compiled/memory/larson/13-jemalloc.tsv',
#                'results_compiled/memory/larson/12-jemalloc.tsv',
#                'results_compiled/memory/larson/0-jemalloc.tsv',
#                'results_compiled/memory/larson/8-jemalloc.tsv',
#                'results_compiled/memory/larson/3-jemalloc.tsv',
#                'results_compiled/memory/larson/14-jemalloc.tsv',
#                'results_compiled/memory/larson/17-jemalloc.tsv',
#                'results_compiled/memory/larson/7-jemalloc.tsv'],
#               'mesh': ['results_compiled/memory/larson/12-mesh.tsv',
#                'results_compiled/memory/larson/10-mesh.tsv',
#                'results_compiled/memory/larson/7-mesh.tsv',
#                'results_compiled/memory/larson/8-mesh.tsv',
#                'results_compiled/memory/larson/17-mesh.tsv',
#                'results_compiled/memory/larson/6-mesh.tsv',
#                'results_compiled/memory/larson/3-mesh.tsv',
#                'results_compiled/memory/larson/9-mesh.tsv',
#                'results_compiled/memory/larson/5-mesh.tsv',
#                'results_compiled/memory/larson/16-mesh.tsv',
#                'results_compiled/memory/larson/11-mesh.tsv',
#                'results_compiled/memory/larson/2-mesh.tsv',
#                'results_compiled/memory/larson/1-mesh.tsv',
#                'results_compiled/memory/larson/19-mesh.tsv',
#                'results_compiled/memory/larson/4-mesh.tsv',
#                'results_compiled/memory/larson/13-mesh.tsv',
#                'results_compiled/memory/larson/14-mesh.tsv',
#                'results_compiled/memory/larson/0-mesh.tsv',
#                'results_compiled/memory/larson/18-mesh.tsv',
#                'results_compiled/memory/larson/15-mesh.tsv'],
#               'malloc': ['results_compiled/memory/larson/9-malloc.tsv',
#                'results_compiled/memory/larson/5-malloc.tsv',
#                'results_compiled/memory/larson/1-malloc.tsv',
#                'results_compiled/memory/larson/18-malloc.tsv',
#                'results_compiled/memory/larson/12-malloc.tsv',
#                'results_compiled/memory/larson/11-malloc.tsv',
#                'results_compiled/memory/larson/13-malloc.tsv',
#                'results_compiled/memory/larson/14-malloc.tsv',
#                'results_compiled/memory/larson/7-malloc.tsv',
#                'results_compiled/memory/larson/8-malloc.tsv',
#                'results_compiled/memory/larson/15-malloc.tsv',
#                'results_compiled/memory/larson/17-malloc.tsv',
#                'results_compiled/memory/larson/16-malloc.tsv',
#                'results_compiled/memory/larson/19-malloc.tsv',
#                'results_compiled/memory/larson/2-malloc.tsv',
#                'results_compiled/memory/larson/10-malloc.tsv',
#                'results_compiled/memory/larson/6-malloc.tsv',
#                'results_compiled/memory/larson/3-malloc.tsv',
#                'results_compiled/memory/larson/4-malloc.tsv',
#                'results_compiled/memory/larson/0-malloc.tsv']}),
#  'redis': defaultdict(list,
#              {'jemalloc': ['results_compiled/memory/redis/2-jemalloc.tsv',
#                'results_compiled/memory/redis/15-jemalloc.tsv',
#                'results_compiled/memory/redis/11-jemalloc.tsv',
#                'results_compiled/memory/redis/4-jemalloc.tsv',
#                'results_compiled/memory/redis/1-jemalloc.tsv',
#                'results_compiled/memory/redis/6-jemalloc.tsv',
#                'results_compiled/memory/redis/10-jemalloc.tsv',
#                'results_compiled/memory/redis/9-jemalloc.tsv',
#                'results_compiled/memory/redis/18-jemalloc.tsv',
#                'results_compiled/memory/redis/16-jemalloc.tsv',
#                'results_compiled/memory/redis/5-jemalloc.tsv',
#                'results_compiled/memory/redis/19-jemalloc.tsv',
#                'results_compiled/memory/redis/13-jemalloc.tsv',
#                'results_compiled/memory/redis/12-jemalloc.tsv',
#                'results_compiled/memory/redis/0-jemalloc.tsv',
#                'results_compiled/memory/redis/8-jemalloc.tsv',
#                'results_compiled/memory/redis/3-jemalloc.tsv',
#                'results_compiled/memory/redis/14-jemalloc.tsv',
#                'results_compiled/memory/redis/17-jemalloc.tsv',
#                'results_compiled/memory/redis/7-jemalloc.tsv'],
#               'mesh': ['results_compiled/memory/redis/12-mesh.tsv',
#                'results_compiled/memory/redis/10-mesh.tsv',
#                'results_compiled/memory/redis/7-mesh.tsv',
#                'results_compiled/memory/redis/8-mesh.tsv',
#                'results_compiled/memory/redis/17-mesh.tsv',
#                'results_compiled/memory/redis/6-mesh.tsv',
#                'results_compiled/memory/redis/3-mesh.tsv',
#                'results_compiled/memory/redis/9-mesh.tsv',
#                'results_compiled/memory/redis/5-mesh.tsv',
#                'results_compiled/memory/redis/16-mesh.tsv',
#                'results_compiled/memory/redis/11-mesh.tsv',
#                'results_compiled/memory/redis/2-mesh.tsv',
#                'results_compiled/memory/redis/1-mesh.tsv',
#                'results_compiled/memory/redis/19-mesh.tsv',
#                'results_compiled/memory/redis/4-mesh.tsv',
#                'results_compiled/memory/redis/13-mesh.tsv',
#                'results_compiled/memory/redis/14-mesh.tsv',
#                'results_compiled/memory/redis/0-mesh.tsv',
#                'results_compiled/memory/redis/18-mesh.tsv',
#                'results_compiled/memory/redis/15-mesh.tsv'],
#               'malloc': ['results_compiled/memory/redis/9-malloc.tsv',
#                'results_compiled/memory/redis/5-malloc.tsv',
#                'results_compiled/memory/redis/1-malloc.tsv',
#                'results_compiled/memory/redis/18-malloc.tsv',
#                'results_compiled/memory/redis/12-malloc.tsv',
#                'results_compiled/memory/redis/11-malloc.tsv',
#                'results_compiled/memory/redis/13-malloc.tsv',
#                'results_compiled/memory/redis/14-malloc.tsv',
#                'results_compiled/memory/redis/7-malloc.tsv',
#                'results_compiled/memory/redis/8-malloc.tsv',
#                'results_compiled/memory/redis/15-malloc.tsv',
#                'results_compiled/memory/redis/17-malloc.tsv',
#                'results_compiled/memory/redis/16-malloc.tsv',
#                'results_compiled/memory/redis/19-malloc.tsv',
#                'results_compiled/memory/redis/2-malloc.tsv',
#                'results_compiled/memory/redis/10-malloc.tsv',
#                'results_compiled/memory/redis/6-malloc.tsv',
#                'results_compiled/memory/redis/3-malloc.tsv',
#                'results_compiled/memory/redis/4-malloc.tsv',
#                'results_compiled/memory/redis/0-malloc.tsv']}),
#  'firefox': defaultdict(list,
#              {'libc': ['results_compiled/memory/firefox/speedometer.libc.1606977054.063035071-5e49ea1c.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606976419.930657225-b4bf8b21.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606972329.422575836-bb3353d7.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606972636.830434526-b477e621.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606975172.602975622-a51e1278.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606975479.082895000-8156cee8.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606975795.769624362-3fce4dbc.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606973587.921962837-3b087685.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606973270.529492356-40342acd.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606976112.367070772-9e68f5b7.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606976736.534621236-27d09523.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606972012.685420427-2bc2b82d.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606974537.626379828-aa928b98.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606974221.842087247-786e1e5f.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606973905.866510719-10956e3c.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606977371.178653437-1d015031.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606974854.621765833-8a34c95f.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606977688.010543377-53d7c440.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606978005.253854363-41eff197.tsv',
#                'results_compiled/memory/firefox/speedometer.libc.1606972953.442338797-583f97c5.tsv'],
#               'mesh': ['results_compiled/memory/firefox/speedometer.mesh.1606972841.389800325-4a864c91.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606975059.405599308-94e62cf6.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606972533.700499073-3378c7cf.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606976624.066285950-da68fc9d.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606976941.268745496-5595e121.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606973792.885481285-97504fcc.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606977892.305724925-54d8483f.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606977258.540400648-ffb63f9b.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606973157.897596502-0d653fa1.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606971899.986871337-9343c08d.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606975376.877929207-e7a13027.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606976317.241677611-8474601c.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606974109.860853561-2cfe1ffa.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606972217.385362519-4f07c203.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606975999.469283473-a8074b53.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606974425.001679014-3d569f0f.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606974742.453965969-686035bc.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606973475.417261266-c868d8f6.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606975682.850863587-dead30f7.tsv',
#                'results_compiled/memory/firefox/speedometer.mesh.1606977575.498983144-ba27d900.tsv'],
#               'jemalloc': ['results_compiled/memory/firefox/speedometer.jemalloc.1606976214.843282486-2dfa488e.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606977156.235050971-e04c1f44.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606973690.217768377-6bbb13a6.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606976838.798894948-989e635f.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606974007.246813762-68755fa7.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606978107.634949979-cf18cccd.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606973372.999988405-2ee0da0a.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606975581.003172373-e429b12c.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606975274.535340318-10435125.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606977473.270921507-207f4044.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606972114.547682004-2f2a9dbd.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606974956.838896035-b24b8990.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606974323.146108491-35e92ba7.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606977789.894214960-3f50f2e4.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606975897.402809037-b197796c.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606972738.611561836-76471408.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606972431.280623390-493d50c9.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606976521.854314672-d84cabda.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606973055.380326136-6d70da4a.tsv',
#                'results_compiled/memory/firefox/speedometer.jemalloc.1606974639.959141957-6a8d5818.tsv']}),
#  'mysql': defaultdict(list,
#              {'jemalloc': ['results_compiled/memory/mysql/2-jemalloc.tsv',
#                'results_compiled/memory/mysql/15-jemalloc.tsv',
#                'results_compiled/memory/mysql/11-jemalloc.tsv',
#                'results_compiled/memory/mysql/4-jemalloc.tsv',
#                'results_compiled/memory/mysql/1-jemalloc.tsv',
#                'results_compiled/memory/mysql/6-jemalloc.tsv',
#                'results_compiled/memory/mysql/10-jemalloc.tsv',
#                'results_compiled/memory/mysql/9-jemalloc.tsv',
#                'results_compiled/memory/mysql/18-jemalloc.tsv',
#                'results_compiled/memory/mysql/16-jemalloc.tsv',
#                'results_compiled/memory/mysql/5-jemalloc.tsv',
#                'results_compiled/memory/mysql/19-jemalloc.tsv',
#                'results_compiled/memory/mysql/13-jemalloc.tsv',
#                'results_compiled/memory/mysql/12-jemalloc.tsv',
#                'results_compiled/memory/mysql/0-jemalloc.tsv',
#                'results_compiled/memory/mysql/8-jemalloc.tsv',
#                'results_compiled/memory/mysql/3-jemalloc.tsv',
#                'results_compiled/memory/mysql/14-jemalloc.tsv',
#                'results_compiled/memory/mysql/17-jemalloc.tsv',
#                'results_compiled/memory/mysql/7-jemalloc.tsv'],
#               'mesh': ['results_compiled/memory/mysql/12-mesh.tsv',
#                'results_compiled/memory/mysql/10-mesh.tsv',
#                'results_compiled/memory/mysql/7-mesh.tsv',
#                'results_compiled/memory/mysql/8-mesh.tsv',
#                'results_compiled/memory/mysql/17-mesh.tsv',
#                'results_compiled/memory/mysql/6-mesh.tsv',
#                'results_compiled/memory/mysql/3-mesh.tsv',
#                'results_compiled/memory/mysql/9-mesh.tsv',
#                'results_compiled/memory/mysql/5-mesh.tsv',
#                'results_compiled/memory/mysql/16-mesh.tsv',
#                'results_compiled/memory/mysql/11-mesh.tsv',
#                'results_compiled/memory/mysql/2-mesh.tsv',
#                'results_compiled/memory/mysql/1-mesh.tsv',
#                'results_compiled/memory/mysql/19-mesh.tsv',
#                'results_compiled/memory/mysql/4-mesh.tsv',
#                'results_compiled/memory/mysql/13-mesh.tsv',
#                'results_compiled/memory/mysql/14-mesh.tsv',
#                'results_compiled/memory/mysql/0-mesh.tsv',
#                'results_compiled/memory/mysql/18-mesh.tsv',
#                'results_compiled/memory/mysql/15-mesh.tsv'],
#               'malloc': ['results_compiled/memory/mysql/9-malloc.tsv',
#                'results_compiled/memory/mysql/5-malloc.tsv',
#                'results_compiled/memory/mysql/1-malloc.tsv',
#                'results_compiled/memory/mysql/18-malloc.tsv',
#                'results_compiled/memory/mysql/12-malloc.tsv',
#                'results_compiled/memory/mysql/11-malloc.tsv',
#                'results_compiled/memory/mysql/13-malloc.tsv',
#                'results_compiled/memory/mysql/14-malloc.tsv',
#                'results_compiled/memory/mysql/7-malloc.tsv',
#                'results_compiled/memory/mysql/8-malloc.tsv',
#                'results_compiled/memory/mysql/15-malloc.tsv',
#                'results_compiled/memory/mysql/17-malloc.tsv',
#                'results_compiled/memory/mysql/16-malloc.tsv',
#                'results_compiled/memory/mysql/19-malloc.tsv',
#                'results_compiled/memory/mysql/2-malloc.tsv',
#                'results_compiled/memory/mysql/10-malloc.tsv',
#                'results_compiled/memory/mysql/6-malloc.tsv',
#                'results_compiled/memory/mysql/3-malloc.tsv',
#                'results_compiled/memory/mysql/4-malloc.tsv',
#                'results_compiled/memory/mysql/0-malloc.tsv']})}

# %%
import numpy as np
from scipy.stats import sem, t

def compute_stats(samples):
    max_value = max(samples)
    ninetieth_percentile = np.percentile(samples, 90)
    mean = np.mean(samples)
    std_err = sem(samples)
    return {
        "max": max_value,
        "90th_percentile": ninetieth_percentile,
        "mean": mean,
        "std_err": std_err,
    }

def parse_file(filename):
    with open(filename, "r") as f:
        reader = csv.DictReader(f, delimiter="\t")
        return [int(row["rss"]) + int(row["kernel"]) for row in reader]

confidence = 0.95
    
def compute_stats_across_runs(files):
    stats = defaultdict(list)
    for file in files:
        run_stats = compute_stats(parse_file(file))
        for key in run_stats:
            stats[key].append(run_stats[key])
    summary_stats = {}
    for stat in stats:
        mean = np.mean(stats[stat])
        std_err = sem(stats[stat])
        ci_term = std_err*t.ppf((1+confidence)/2, len(stats[stat])-1)
        summary_stats[stat] = (mean-ci_term, mean+ci_term)
    return summary_stats

# %%
for program in data:
    for allocator in data[program]:
        print(f"Stats for {program} ({allocator}):")
        for stat, value in compute_stats_across_runs(data[program][allocator]).items():
            print(f"\t{stat}:\t\t{value}")
    print()
# Out:
# Stats for binarytree (jemalloc):
# 	max:		(207753744.01628643, 207906287.98371357)
# 	90th_percentile:		(133303939.18847826, 134870970.25152174)
# 	mean:		(88390769.19503106, 88662491.50577323)
# 	std_err:		(450028.651085527, 456692.91536644375)
# Stats for binarytree (mesh):
# 	max:		(208037993.3746195, 208210633.82538047)
# 	90th_percentile:		(154285632.5038758, 155828057.09612423)
# 	mean:		(96559085.24153914, 96946699.36401667)
# 	std_err:		(544815.1932084257, 554712.7500135851)
# Stats for binarytree (malloc):
# 	max:		(203243836.51576847, 203386563.48423153)
# 	90th_percentile:		(203243836.51576847, 203386563.48423153)
# 	mean:		(144601162.59121028, 144844984.61192164)
# 	std_err:		(400458.4739449383, 405454.3016543577)
# Stats for binarytree (libc):
#
# Stats for larson (jemalloc):
# 	max:		(5080253.116285665, 5287132.483714335)
# 	90th_percentile:		(4910373.83322069, 5088371.76677931)
# 	mean:		(4305644.441617002, 4429319.51734369)
# 	std_err:		(15943.741775650358, 17623.387724537573)
# Stats for larson (mesh):
# 	max:		(6019898.793707564, 6293086.806292436)
# 	90th_percentile:		(5849425.598761766, 6110894.401238234)
# 	mean:		(5185142.594851099, 5377608.8337964695)
# 	std_err:		(18203.75092003829, 20153.765688798132)
# Stats for larson (malloc):
# 	max:		(5065449.570684889, 5297430.429315111)
# 	90th_percentile:		(4870989.3245473225, 5122021.875452677)
# 	mean:		(4165305.2527010473, 4306046.31345485)
# 	std_err:		(16766.731906609904, 18882.37913825647)
#
# Stats for redis (jemalloc):
# 	max:		(291789009.36481595, 291993390.63518405)
# 	90th_percentile:		(291676094.95791775, 291885121.04208225)
# 	mean:		(224123319.3833175, 226591742.0134255)
# 	std_err:		(1526881.5872329567, 1548381.5778903207)
# Stats for redis (mesh):
# 	max:		(272009084.06551665, 273807082.3344833)
# 	90th_percentile:		(234970610.58151636, 236191327.33848372)
# 	mean:		(182095816.7120705, 182570995.8802549)
# 	std_err:		(841382.1654856798, 849626.2489371569)
# Stats for redis (malloc):
# 	max:		(264969692.58240923, 265177225.81759074)
# 	90th_percentile:		(264920510.5138096, 265133674.44619045)
# 	mean:		(255116835.36792976, 255348431.99985665)
# 	std_err:		(982980.3913695947, 996897.9576928455)
#
# Stats for firefox (libc):
# 	max:		(874952305.8052888, 908319937.3947113)
# 	90th_percentile:		(817787215.4625618, 855852597.657438)
# 	mean:		(700069177.5141784, 726546867.094788)
# 	std_err:		(4682831.288175494, 5112431.886278509)
# Stats for firefox (mesh):
# 	max:		(978692503.0732535, 1024945768.9267465)
# 	90th_percentile:		(863587988.0329434, 894647209.4070565)
# 	mean:		(729344653.4741573, 745026966.7048149)
# 	std_err:		(3757212.407209684, 4108764.527165967)
# Stats for firefox (jemalloc):
# 	max:		(692245384.8684144, 731414851.9315856)
# 	90th_percentile:		(640106049.7799082, 674951819.020092)
# 	mean:		(565965444.8853503, 591192558.0589517)
# 	std_err:		(3171212.507260715, 3532189.810911954)
#
# Stats for mysql (jemalloc):
# 	max:		(231877114.38461342, 232173061.61538658)
# 	90th_percentile:		(231637892.11637834, 231915643.88362166)
# 	mean:		(223876345.4354545, 224291609.29711616)
# 	std_err:		(227923.88861775064, 237423.45704403837)
# Stats for mysql (mesh):
# 	max:		(273812497.3493348, 274168814.6506652)
# 	90th_percentile:		(273529781.4830959, 273831805.71690416)
# 	mean:		(264841156.4629398, 265287482.2819863)
# 	std_err:		(273853.60672978347, 287697.011046492)
# Stats for mysql (malloc):
# 	max:		(228298118.6374982, 228564396.5625018)
# 	90th_percentile:		(227915579.1523956, 228229316.8476044)
# 	mean:		(220480804.47763115, 221017988.8148921)
# 	std_err:		(222171.7022865017, 233116.82275803544)
